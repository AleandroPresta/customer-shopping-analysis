# %% [markdown]
# # Customer Shopping Trends Analysis
#
# ## Introduction
#
# This analysis explores customer shopping behavior using a dataset of 3,336 records containing information about purchases including customer demographics, item details, purchase amounts, and shopping preferences. The dataset includes features such as age, gender, item categories, prices, locations, sizes, seasons, and payment methods.
#
# ## Data Exploration
# ### Importing the dataset

# %%
import pandas as pd

def load_shopping_data(data_path: str):
    return pd.read_csv(data_path)

# %%
DATA_PATH = '../data/shopping_trends.csv'
shopping_data = load_shopping_data(DATA_PATH)
shopping_data.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %% [markdown]
# ### Preliminary Exploration

# %%
shopping_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %% [markdown]
# Inside our dataset we have 19 columns:
# 1. **Customer ID**: A unique identifier for each customer (integer).
# 2. **Age**: The age of the customer (integer).
# 3. **Gender**: The gender of the customer.
# 4. **Item Purchased**: The name or identifier of the item purchased.
# 5. **Category**: The category to which the purchased item belongs.
# 6. **Purchase Amount (USD)**: The amount spent on the purchase in US dollars (integer).
# 7. **Location**: The location where the purchase was made.
# 8. **Size**: The size of the purchased item.
# 9. **Color**: The color of the purchased item.
# 10. **Season**: The season during which the purchase was made.
# 11. **Review Rating**: The rating given by the customer for the purchase (float).
# 12. **Subscription Status**: Indicates whether the customer has a subscription.
# 13. **Payment Method**: The method used for payment.
# 14. **Shipping Type**: The type of shipping chosen for the purchase.
# 15. **Discount Applied**: Indicates whether a discount was applied to the purchase.
# 16. **Promo Code Used**: Indicates whether a promo code was used
# 17. **Previous Purchases**: The number of previous purchases made by the customer (integer).
# 18. **Preferred Payment Method**: The customer's preferred method of payment.
# 19. **Frequency of Purchases**: How often the customer makes purchases.

# %%
shopping_data.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %% [markdown]
# ### Categorical Exploration
# For each categorical column we are gonna explore which values are available and how many rows have a certain categorical value.
#
# We start with the gender of the purchaser:

# %%
gender_counts = shopping_data['Gender'].value_counts()
gender_counts
# Out:
# Male      2652
# Female    1248
# Name: Gender, dtype: int64

# %% [markdown]
# The number of purchases made by male customers almost doubles the number of purchases made by female customers. We can see this better using a pie chart:

# %%
import matplotlib.pyplot as plt

gender_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff'], legend=True)
plt.ylabel('')
plt.title('Gender Distribution')
plt.show()

# %% [markdown]
# Next we are gonna explore the items purchased, using a histogram:

# %%
import seaborn as sns

def plot_item_distribution(column_name: str):
    item_count = shopping_data[column_name].value_counts()
    plt.figure(figsize=(12, 8))
    sns.barplot(x=item_count.values, y=item_count.index, order=item_count.index)
    plt.xlabel('Number of Purchases')
    plt.ylabel(column_name)
    plt.show()

plot_item_distribution('Item Purchased')

# %% [markdown]
# The most purchased items are Blouses, Pants and Jewelry.

# %%
category_counts = shopping_data['Category'].value_counts()
category_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, legend=True)
plt.ylabel('')
plt.title('Category Distribution')
plt.show()

# %% [markdown]
# This category has only 4 possible values and most of the items purchased are clothes.

# %%
plot_item_distribution('Location')

# %% [markdown]
# Plotting the `Location` of the purchases shows us that all of them are made in the US. The clients are spread all over the state but the states with the highest number of purchases are `Montana`, `California` and `Idaho`.

# %%
size_counts = shopping_data['Size'].value_counts()
size_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, legend=True)
plt.ylabel('')
plt.title('Size Distribution')
plt.show()

# %% [markdown]
# The most common size is M followed by L, S and XL.

# %%
plot_item_distribution('Color')

# %% [markdown]
# The preferred color is Olive, followed by Yellow and Silver.

# %%
plot_item_distribution('Subscription Status')

# %% [markdown]
# Most of the purchases are made by customers without a subscription

# %%
plot_item_distribution('Payment Method')

# %% [markdown]
# Only a little more then 600 of the total purchases are made paying with cash.

# %%
plot_item_distribution('Frequency of Purchases')

# %% [markdown]
# Most of the users buy something every 3 months or once a year.
#
# The other categorical attributes don't provide any useful information for the analysis.
# ### Numerical Exploration
# Here follows the exploration of the numerical attributes of the dataset.

# %%
def plot_numerical_distribution(column_name: str):
    plt.figure(figsize=(12, 8))
    sns.histplot(shopping_data[column_name], kde=True, color='skyblue', bins=30)
    plt.xlabel(column_name, fontsize=14)
    plt.ylabel('Number of purchases', fontsize=14)
    plt.title(f'Distribution of {column_name}', fontsize=16)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.show()
    
plot_numerical_distribution('Age')

# %% [markdown]
# The age distribution is quite varied and doesn't provide any clear insight.

# %%
plot_numerical_distribution('Purchase Amount (USD)')

# %% [markdown]
# The amount of purchases varies between 20 and 100 USD. There isn't really a pattern in the purchase amount.

# %%
plot_numerical_distribution('Review Rating')

# %% [markdown]
# The review rating varies between 2.5 and 5. In this attribute there is also no clear pattern.
# ### Correlations
# In this paragraph we are gonna explore the correlation between each pair of attributes.

# %%
def plot_correlation_matrix(data):
    plt.figure(figsize=(14, 10))
    sns.heatmap(data.corr(), annot=True, cmap='coolwarm', linewidths=.5)
    plt.title('Correlation Matrix')
    plt.show()

plot_correlation_matrix(shopping_data)

# %% [markdown]
# The correlation matrix shows that here isn't a strong correlation between any pair of attributes inside the dataset. This can also be seen in the following scatterplot matrix.

# %%
pd.plotting.scatter_matrix(shopping_data, figsize=(12, 8))
# Out:
# array([[<AxesSubplot:xlabel='Customer ID', ylabel='Customer ID'>,
#         <AxesSubplot:xlabel='Age', ylabel='Customer ID'>,
#         <AxesSubplot:xlabel='Purchase Amount (USD)', ylabel='Customer ID'>,
#         <AxesSubplot:xlabel='Review Rating', ylabel='Customer ID'>,
#         <AxesSubplot:xlabel='Previous Purchases', ylabel='Customer ID'>],
#        [<AxesSubplot:xlabel='Customer ID', ylabel='Age'>,
#         <AxesSubplot:xlabel='Age', ylabel='Age'>,
#         <AxesSubplot:xlabel='Purchase Amount (USD)', ylabel='Age'>,
#         <AxesSubplot:xlabel='Review Rating', ylabel='Age'>,
#         <AxesSubplot:xlabel='Previous Purchases', ylabel='Age'>],
#        [<AxesSubplot:xlabel='Customer ID', ylabel='Purchase Amount (USD)'>,
#         <AxesSubplot:xlabel='Age', ylabel='Purchase Amount (USD)'>,
#         <AxesSubplot:xlabel='Purchase Amount (USD)', ylabel='Purchase Amount (USD)'>,
#         <AxesSubplot:xlabel='Review Rating', ylabel='Purchase Amount (USD)'>,
# ...
